# %% [markdown]
# # Import the Data
#
# We are exploring StackOverflow Annual Developer survey data from 2019. The data is available at:
# * https://insights.stackoverflow.com/survey in CSV format

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import pymongo
from pymongo import MongoClient
import json
from datetime import datetime

# %%
data = pd.read_csv("./data/developer_survey_2019/survey_results_public.csv")

# %%
data.shape
# Out:
# (88883, 85)

# %%
data.columns
# Out:
# Index(['Respondent', 'MainBranch', 'Hobbyist', 'OpenSourcer', 'OpenSource',
#        'Employment', 'Country', 'Student', 'EdLevel', 'UndergradMajor',
#        'EduOther', 'OrgSize', 'DevType', 'YearsCode', 'Age1stCode',
#        'YearsCodePro', 'CareerSat', 'JobSat', 'MgrIdiot', 'MgrMoney',
#        'MgrWant', 'JobSeek', 'LastHireDate', 'LastInt', 'FizzBuzz',
#        'JobFactors', 'ResumeUpdate', 'CurrencySymbol', 'CurrencyDesc',
#        'CompTotal', 'CompFreq', 'ConvertedComp', 'WorkWeekHrs', 'WorkPlan',
#        'WorkChallenge', 'WorkRemote', 'WorkLoc', 'ImpSyn', 'CodeRev',
#        'CodeRevHrs', 'UnitTests', 'PurchaseHow', 'PurchaseWhat',
#        'LanguageWorkedWith', 'LanguageDesireNextYear', 'DatabaseWorkedWith',
#        'DatabaseDesireNextYear', 'PlatformWorkedWith',
#        'PlatformDesireNextYear', 'WebFrameWorkedWith',
#        'WebFrameDesireNextYear', 'MiscTechWorkedWith',
#        'MiscTechDesireNextYear', 'DevEnviron', 'OpSys', 'Containers',
#        'BlockchainOrg', 'BlockchainIs', 'BetterLife', 'ITperson', 'OffOn',
#        'SocialMedia', 'Extraversion', 'ScreenName', 'SOVisit1st',
#        'SOVisitFreq', 'SOVisitTo', 'SOFindAnswer', 'SOTimeSaved',
#        'SOHowMuchTime', 'SOAccount', 'SOPartFreq', 'SOJobs', 'EntTeams',
#        'SOComm', 'WelcomeChange', 'SONewContent', 'Age', 'Gender', 'Trans',
#        'Sexuality', 'Ethnicity', 'Dependents', 'SurveyLength', 'SurveyEase'],
#       dtype='object')

# %% [markdown]
# The data is pretty large. It consists of inputs from almost 89,000 developers. The data is multidimensional. It has 85 columns. Since not all the columns will be used in our analysis we will trim down the dataset as much as we need.

# %% [markdown]
# # Data Cleaning
#
# Right below we are eliminating the rows where Language Worked With column is not filled. This is a developer survey and we expect to have at least one language in that column.

# %%
cleaned_data = data[pd.notnull(data['LanguageWorkedWith'])]

# %%
# Below is convenient method to visualize all columns and their calues in jupyter notebook. Based on the below
#information we will decide on which columns to keep.
cleaned_data.iloc[1].to_dict()
# Out:
# {'Respondent': 2,
#  'MainBranch': 'I am a student who is learning to code',
#  'Hobbyist': 'No',
#  'OpenSourcer': 'Less than once per year',
#  'OpenSource': 'The quality of OSS and closed source software is about the same',
#  'Employment': 'Not employed, but looking for work',
#  'Country': 'Bosnia and Herzegovina',
#  'Student': 'Yes, full-time',
#  'EdLevel': 'Secondary school (e.g. American high school, German Realschule or Gymnasium, etc.)',
#  'UndergradMajor': nan,
#  'EduOther': 'Taken an online course in programming or software development (e.g. a MOOC)',
#  'OrgSize': nan,
#  'DevType': 'Developer, desktop or enterprise applications;Developer, front-end',
#  'YearsCode': nan,
#  'Age1stCode': '17',
#  'YearsCodePro': nan,
#  'CareerSat': nan,
#  'JobSat': nan,
#  'MgrIdiot': nan,
#  'MgrMoney': nan,
#  'MgrWant': nan,
#  'JobSeek': 'I am actively looking for a job',
#  'LastHireDate': "I've never had a job",
#  'LastInt': nan,
#  'FizzBuzz': nan,
#  'JobFactors': "Financial performance or funding status of the company or organization;Specific department or team I'd be working on;Languages, frameworks, and other technologies I'd be working with",
#  'ResumeUpdate': 'Something else changed (education, award, media, etc.)',
#  'CurrencySymbol': nan,
#  'CurrencyDesc': nan,
#  'CompTotal': nan,
#  'CompFreq': nan,
#  'ConvertedComp': nan,
#  'WorkWeekHrs': nan,
#  'WorkPlan': nan,
#  'WorkChallenge': nan,
#  'WorkRemote': nan,
#  'WorkLoc': nan,
#  'ImpSyn': nan,
#  'CodeRev': nan,
#  'CodeRevHrs': nan,
#  'UnitTests': nan,
#  'PurchaseHow': nan,
#  'PurchaseWhat': nan,
#  'LanguageWorkedWith': 'C++;HTML/CSS;Python',
#  'LanguageDesireNextYear': 'C++;HTML/CSS;JavaScript;SQL',
#  'DatabaseWorkedWith': nan,
#  'DatabaseDesireNextYear': 'MySQL',
#  'PlatformWorkedWith': 'Windows',
#  'PlatformDesireNextYear': 'Windows',
#  'WebFrameWorkedWith': 'Django',
#  'WebFrameDesireNextYear': 'Django',
#  'MiscTechWorkedWith': nan,
#  'MiscTechDesireNextYear': nan,
#  'DevEnviron': 'Atom;PyCharm',
#  'OpSys': 'Windows',
#  'Containers': 'I do not use containers',
#  'BlockchainOrg': nan,
#  'BlockchainIs': 'Useful across many domains and could change many aspects of our lives',
#  'BetterLife': 'Yes',
#  'ITperson': 'Yes',
#  'OffOn': 'Yes',
#  'SocialMedia': 'Instagram',
#  'Extraversion': 'Online',
#  'ScreenName': 'Username',
#  'SOVisit1st': '2017',
#  'SOVisitFreq': 'Daily or almost daily',
#  'SOVisitTo': 'Find answers to specific questions;Learn how to do things I didn’t necessarily look for',
#  'SOFindAnswer': '3-5 times per week',
#  'SOTimeSaved': 'Stack Overflow was much faster',
#  'SOHowMuchTime': '11-30 minutes',
#  'SOAccount': 'Yes',
#  'SOPartFreq': 'A few times per month or weekly',
#  'SOJobs': 'No, I knew that Stack Overflow had a job board but have never used or visited it',
#  'EntTeams': "No, and I don't know what those are",
#  'SOComm': 'Yes, somewhat',
#  'WelcomeChange': 'Just as welcome now as I felt last year',
#  'SONewContent': "Tech articles written by other developers;Industry news about technologies you're interested in;Tech meetups or events in your area;Courses on technologies you're interested in",
#  'Age': 19.0,
#  'Gender': 'Man',
#  'Trans': 'No',
#  'Sexuality': 'Straight / Heterosexual',
#  'Ethnicity': nan,
#  'Dependents': 'No',
#  'SurveyLength': 'Appropriate in length',
#  'SurveyEase': 'Neither easy nor difficult'}

# %% [markdown]
# Below is the filter mask we created containing all the columns we need for our analysis

# %%
column_mask = ["MainBranch", "Hobbyist", "Employment", "DevType", "Country", "EdLevel", "YearsCode", "ConvertedComp", "JobSat", "JobSeek", "LanguageWorkedWith", "DatabaseWorkedWith", "WebFrameWorkedWith", "SOVisitFreq", "Age", "Gender"]

# %%
# Apply mask
simple_data = cleaned_data[column_mask]

# %%
simple_data = simple_data[simple_data.LanguageWorkedWith.notnull() & simple_data.ConvertedComp.notnull() & simple_data.JobSat.notnull() & simple_data.DevType.notnull()]

# %%
simple_data
# Out:
#                                               MainBranch Hobbyist  \
# 2      I am not primarily a developer, but I write co...      Yes
# 3                         I am a developer by profession       No
# 5      I am not primarily a developer, but I write co...      Yes
# 8                         I am a developer by profession      Yes
# 9                         I am a developer by profession      Yes
# ...                                                  ...      ...
# 88325                     I am a developer by profession      Yes
# 88326                     I am a developer by profession      Yes
# 88328                     I am a developer by profession      Yes
# 88329                     I am a developer by profession      Yes
# 88330                     I am a developer by profession      Yes
#
#                Employment                                            DevType  \
# 2      Employed full-time  Designer;Developer, back-end;Developer, front-...
# 3      Employed full-time                              Developer, full-stack
# 5      Employed full-time  Data or business analyst;Data scientist or mac...
# 8      Employed full-time  Database administrator;Developer, back-end;Dev...
# 9      Employed full-time  Data or business analyst;Data scientist or mac...
# ...                   ...                                                ...
# 88325  Employed full-time  Developer, back-end;Developer, front-end;Devel...
# 88326  Employed full-time  Developer, desktop or enterprise applications;...
# 88328  Employed full-time   Developer, full-stack;Engineer, site reliability
# 88329  Employed full-time  Academic researcher;Database administrator;Dev...
# 88330  Employed full-time  Developer, back-end;Developer, desktop or ente...
#
#              Country                                            EdLevel  \
# 2           Thailand           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 3      United States           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 5             Canada           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 8        New Zealand  Some college/university study without earning ...
# 9              India        Master’s degree (MA, MS, M.Eng., MBA, etc.)
# ...              ...                                                ...
# 88325  United States           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 88326        Finland        Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 88328        Austria        Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 88329    Netherlands        Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 88330         Greece           Bachelor’s degree (BA, BS, B.Eng., etc.)
#
#       YearsCode  ConvertedComp                              JobSat  \
# 2             3         8820.0                  Slightly satisfied
# 3             3        61000.0                  Slightly satisfied
# 5            13       366420.0                  Slightly satisfied
# 8            12        95179.0                  Slightly satisfied
# 9            12        13293.0               Slightly dissatisfied
# ...         ...            ...                                 ...
# 88325        12       130000.0                      Very satisfied
# 88326        17        82488.0  Neither satisfied nor dissatisfied
# 88328        18        68745.0  Neither satisfied nor dissatisfied
# 88329        10       588012.0                   Very dissatisfied
# 88330         9        22915.0               Slightly dissatisfied
#
#                                                  JobSeek  \
# 2      I’m not actively looking, but I am open to new...
# 3           I am not interested in new job opportunities
# 5           I am not interested in new job opportunities
# 8      I’m not actively looking, but I am open to new...
# 9      I’m not actively looking, but I am open to new...
# ...                                                  ...
# 88325       I am not interested in new job opportunities
# 88326  I’m not actively looking, but I am open to new...
# 88328       I am not interested in new job opportunities
# 88329  I’m not actively looking, but I am open to new...
# 88330  I’m not actively looking, but I am open to new...
#
#                                       LanguageWorkedWith  \
# 2                                               HTML/CSS
# 3                                    C;C++;C#;Python;SQL
# 5                                             Java;R;SQL
# 8      Bash/Shell/PowerShell;C#;HTML/CSS;JavaScript;P...
# 9                          C#;Go;JavaScript;Python;R;SQL
# ...                                                  ...
# 88325               HTML/CSS;JavaScript;Scala;TypeScript
# 88326                   Bash/Shell/PowerShell;C++;Python
# 88328  Bash/Shell/PowerShell;Go;HTML/CSS;Java;JavaScr...
# 88329             C#;HTML/CSS;Java;JavaScript;PHP;Python
# 88330              Go;HTML/CSS;Java;JavaScript;Other(s):
#
#                                       DatabaseWorkedWith  \
# 2                                             PostgreSQL
# 3                                           MySQL;SQLite
# 5                                     MongoDB;PostgreSQL
# 8                             DynamoDB;PostgreSQL;SQLite
# 9      Elasticsearch;MongoDB;Microsoft SQL Server;MyS...
# ...                                                  ...
# 88325                                         PostgreSQL
# 88326                                                NaN
# 88328                                   PostgreSQL;Redis
# 88329                                 MariaDB;PostgreSQL
# 88330                Cassandra;MariaDB;PostgreSQL;SQLite
#
#                                       WebFrameWorkedWith  \
# 2                                                    NaN
# 3                                                    NaN
# 5                                                    NaN
# 8                        Express;Ruby on Rails;Other(s):
# 9      Angular/Angular.js;ASP.NET;Django;Express;Flas...
# ...                                                  ...
# 88325                                 React.js;Other(s):
# 88326                                                NaN
# 88328                                    Django;React.js
# 88329                                    jQuery;React.js
# 88330                                      Spring;Vue.js
#
#                            SOVisitFreq   Age Gender
# 2                 A few times per week  28.0    Man
# 3                Daily or almost daily  22.0    Man
# 5      A few times per month or weekly  28.0    Man
# 8                Daily or almost daily  23.0    Man
# 9               Multiple times per day   NaN    NaN
# ...                                ...   ...    ...
# 88325           Multiple times per day  26.0    Man
# 88326  A few times per month or weekly  34.0    Man
# 88328  A few times per month or weekly  37.0    Man
# 88329             A few times per week   NaN    Man
# 88330             A few times per week  33.0    Man
#
# [54844 rows x 16 columns]

# %%
q1 = np.percentile(simple_data.ConvertedComp.values, 25)
q2 = np.percentile(simple_data.ConvertedComp.values, 50)
q3 = np.percentile(simple_data.ConvertedComp.values, 75)
iqr = q3 - q1

upper_boundary = q3 + 1.5*iqr
lower_boundary = q1 - 1.5*iqr
    
    # Determine if there are outliers
outlier1 = (simple_data.ConvertedComp > upper_boundary)
outlier2 = (simple_data.ConvertedComp < lower_boundary)

# %% [markdown]
# # Database Creation and Data Ingestion
#
# We will be using MongoDB for our database.

# %%
conn = 'mongodb://localhost:27017'
client = pymongo.MongoClient(conn)

# %% [markdown]
# ## Create StackOverFlow database and ingest developers collection into the databse in the form of python dictionary

# %%
db = client.stack_overflow
developers = db.developers_cleaned.find()

# %% [markdown]
# Iterate over simple_data DataFrame and add each row into stack_overflow database as a developer collection. Check for Nan values in "DatabaseWorkedWith" and "WebFrameWorkedWith" columns

# %%
for row in simple_data.itertuples():
    developer_dict = {}
    developer_dict["MainBranch"] = getattr(row, "MainBranch")
    developer_dict["Hobbyist"] = getattr(row, "Hobbyist")
    developer_dict["Employment"] = getattr(row, "Employment")
    developer_dict["DevType"] = getattr(row, "DevType")
    developer_dict["Country"] = getattr(row, "Country")
    developer_dict["EdLevel"] = getattr(row, "EdLevel")
    developer_dict["YearsCode"] = getattr(row, "YearsCode")
    developer_dict["ConvertedComp"] = getattr(row, "ConvertedComp")
    developer_dict["JobSat"] = getattr(row, "JobSat")
    developer_dict["JobSeek"] = getattr(row, "JobSeek")
    developer_dict["LanguageWorkedWith"] = getattr(row, "LanguageWorkedWith")
    if pd.isna(getattr(row, "DatabaseWorkedWith")):
        developer_dict["DatabaseWorkedWith"] = None
    else:
        developer_dict["DatabaseWorkedWith"] = getattr(row, "DatabaseWorkedWith")
    if pd.isna(getattr(row, "WebFrameWorkedWith")):
        developer_dict["WebFrameWorkedWith"] = None
    else:
        developer_dict["WebFrameWorkedWith"] = getattr(row, "WebFrameWorkedWith")
    developer_dict["SOVisitFreq"] = getattr(row, "SOVisitFreq")
    developer_dict["Age"] = getattr(row, "Age")
    developer_dict["Gender"] = getattr(row, "Gender")
    db.developers_cleaned.insert_one(developer_dict)
